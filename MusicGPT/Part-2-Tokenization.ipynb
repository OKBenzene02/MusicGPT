# %% [markdown]
# # Install required packages

# %%
# !pip install pydantic
# !pip install pydantic_argparse
# !pip install music21
# !pip install pandas
# !pip install numpy
# Out:
# ...
#      ---------------------------------------- 0.0/85.1 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/85.1 kB ? eta -:--:--
#      --------- ---------------------------- 20.5/85.1 kB 162.5 kB/s eta 0:00:01
#      ------------- ------------------------ 30.7/85.1 kB 186.2 kB/s eta 0:00:01
#      --------------------------- ---------- 61.4/85.1 kB 297.7 kB/s eta 0:00:01
#      -------------------------------------- 85.1/85.1 kB 366.9 kB/s eta 0:00:00
# ...
#   Using cached annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# ...
#    ---------------------------------------- 0.0/394.9 kB ? eta -:--:--
#    ---------------- ----------------------- 163.8/394.9 kB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 394.9/394.9 kB 4.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    -------------------- ------------------- 0.9/1.9 MB 19.8 MB/s eta 0:00:01
# ...

# %% [markdown]
# # Load the Mulit-track Music Machine tokenizer

# %%
# %cd mmm_tokenizer
# Out:
# c:\Users\liyak\OneDrive\Documents\Python Scripts\Some Projects\Generative Sound\MusicGPT-20240319T052440Z-001\MusicGPT\mmm_tokenizer

# %%
# !dir
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 9A63-B62B
#
#  Directory of c:\Users\liyak\OneDrive\Documents\Python Scripts\Some Projects\Generative Sound\MusicGPT-20240319T052440Z-001\MusicGPT\mmm_tokenizer
#
# 19-03-2024  11:18    <DIR>          .
# 19-03-2024  12:13    <DIR>          ..
# 19-03-2024  11:18               474 .gitignore
# 19-03-2024  11:18             3,449 create_dataset_mmm.py
# 19-03-2024  11:18    <DIR>          datasets
# 19-03-2024  11:18            11,324 LICENSE
# 19-03-2024  11:18               989 README.md
# 19-03-2024  11:18    <DIR>          source
#                4 File(s)         16,236 bytes
#                4 Dir(s)  74,949,414,912 bytes free

# %%
# !python create_dataset_mmm.py --help
# Out:
# usage: MMM Tokenizer LMD Clean [-h] [-v] [--dataset-name DATASET_NAME]
#                                [--encoding-method ENCODING_METHOD]
#                                [--json-data-method JSON_DATA_METHOD]
#                                [--window-size-bars WINDOW_SIZE_BARS]
#                                [--hop-length-bars HOP_LENGTH_BARS]
#                                [--density-bins-number DENSITY_BINS_NUMBER]
#                                [--transpositions-train TRANSPOSITIONS_TRAIN [TRANSPOSITIONS_TRAIN ...]]
#                                [--no-permute-tracks]
#                                [--num-files-per-iteration NUM_FILES_PER_ITERATION]
#                                [--midi-source MIDI_SOURCE]
#                                [--save-path SAVE_PATH]
#
# This programs tokenize the LMD clean dataset using the MMM tokenizer
#
# required arguments:
#   --midi-source MIDI_SOURCE
#                         Folder with the LMD dataset
# ...

# %% [markdown]
# # Change the navigation of source and target datasets

# %%
# !python3 create_dataset_mmm.py --midi-source "test/prompt" --save-path 'test/prompt-tokens' --num-files-per-iteration 1000
# Out:
# 2024-02-28 05:06:48,418 - main - INFO - Creating DatasetCreator
# 2024-02-28 05:06:48,418 - main - INFO - Creating list of path files...
# 2024-02-28 05:06:48,421 - main - INFO - There are 1 midi files in the directory
# 2024-02-28 05:06:48,421 - main - INFO - Creating loader iterator...
# 2024-02-28 05:06:48,429 - main - INFO - Loader iterator ready.
# 2024-02-28 05:06:48,430 - main - INFO - Loading songs
# 2024-02-28 05:06:49,185 - main - INFO - Got 1 songs
# 2024-02-28 05:06:49,191 - music21lmd - INFO - Using 0 for training.
# 2024-02-28 05:06:49,191 - music21lmd - INFO - Using 1 for validation.
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/MusicGPT/mmm_tokenizer/create_dataset_mmm.py", line 93, in <module>
#     main()
#   File "/content/drive/MyDrive/MusicGPT/mmm_tokenizer/create_dataset_mmm.py", line 80, in main
#     dataset_creator.create(
#   File "/content/drive/MyDrive/MusicGPT/mmm_tokenizer/source/datasetcreator.py", line 69, in create
# ...
